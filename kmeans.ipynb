# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (3.5.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib) (21.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting scipy>=1.0
#   Downloading scipy-1.9.0-cp38-cp38-macosx_12_0_universal2.macosx_10_9_x86_64.whl (58.1 MB)
#      |████████████████████████████████| 58.1 MB 17.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: matplotlib>=2.2 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: pandas>=0.23 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from seaborn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.9.0 seaborn-0.11.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp38-cp38-macosx_10_9_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 4.9 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=1.0.0
#   Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Requirement already satisfied: scipy>=1.3.2 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/prarthanabhat/opt/anaconda3/envs/customer_segmentation/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.20.3)
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.1.2 sklearn-0.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### K means Clustering

# %% [markdown]
# k-means clustering is a method of vector quantization, originally from signal processing, that aims to partition n observations into k clusters in which each observation belongs to the cluster with the nearest mean (cluster centers or cluster centroid), serving as a prototype of the cluster,This results in a partitioning of the data space into Voronoi cells Source: Wikipedia

# %% [markdown]
# k-means clustering minimizes within-cluster variances (squared Euclidean distances),

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from sklearn.cluster import KMeans

# %%
from sklearn.datasets import make_blobs
X, y_true = make_blobs(n_samples=400, centers=4, cluster_std=0.8, random_state=0)

# %%
plt.scatter(X[:, 0], X[:, 1], s=20);
plt.show()

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=20, cmap='summer')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='blue', s=100, alpha=0.9);
plt.show()

# %%
ls
# Out:
# README.md     kmeans.ipynb

# %%
git status
# Out:
#   File "/var/folders/z7/krfckrl90rq2fnyjm0129cnw0000gn/T/ipykernel_23772/3528599804.py", line 1
#     git status
#         ^
# SyntaxError: invalid syntax
